# %%
import tensorflow as tf

saved_model_dir = (
  '/Users/garyburgmann/code/gitlab.com/garyburgmann'
  '/image-processing-pi/models'
  '/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model'
)

converter = tf.saved_model.load(saved_model_dir)
# tflite_model = converter.convert()
    
# # Save the TF Lite model.
# with tf.io.gfile.GFile('./model.tflite', 'wb') as f:
#   f.write(tflite_model)

print('done ...')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-2d5ab77fa98b> in <module>
#       8
#       9 converter = tf.saved_model.load(saved_model_dir)
# ---> 10 tflite_model = converter.convert()
#      11
#      12 # Save the TF Lite model.
#
# AttributeError: '_UserObject' object has no attribute 'convert'
